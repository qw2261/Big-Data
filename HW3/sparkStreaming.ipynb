# %% [markdown]
# <h1 align="center">EECS E6893 Big Data Analytics - Homework Assignment 3</h1>
# <h2 align="center">Name: Qi Wang</h2>
# <h2 align="center">UNI: qw2261</h2>
#
#
# This module is the spark streaming analysis process.
#
#
# Usage:
#     If used with dataproc:
#         gcloud dataproc jobs submit pyspark --cluster <Cluster Name> twitterHTTPClient.py
#
#     Create a dataset in BigQurey first using
#         bq mk bigdata_sparkStreaming
#
#     Remeber to replace the bucket with your own bucket name
#
#
# Todo:
#     1. hashtagCount: calculate accumulated hashtags count
#     2. wordCount: calculate word count every 60 seconds
#         the word you should track is listed below.
#     3. save the result to google BigQuery

# %%
from pyspark import SparkConf,SparkContext
from pyspark.streaming import StreamingContext
from pyspark.sql import Row,SQLContext
import sys
import requests
import time
import subprocess
import re
from google.cloud import bigquery

# %%
# global variables
bucket = "big_data_homework3"    # TODO : replace with your own bucket name
output_directory_hashtags = 'gs://{}/hadoop/tmp/bigquery/pyspark_output/hashtagsCount'.format(bucket)
output_directory_wordcount = 'gs://{}/hadoop/tmp/bigquery/pyspark_output/wordcount'.format(bucket)

# %%
# output table and columns name
output_dataset = 'homework0-253123:hw_3'                     #the name of your dataset in BigQuery
output_table_hashtags = 'hashtags'
columns_name_hashtags = ['hashtags', 'count']
output_table_wordcount = 'wordcount'
columns_name_wordcount = ['word', 'count', 'time']

# %%
# parameter
IP = 'localhost'    # ip port
PORT = 9001       # port

STREAMTIME = 600          # time that the streaming process runs

WORD = ['data', 'spark', 'ai', 'movie', 'good']     #the words you should filter and do word count

# %%
# Helper functions
def saveToStorage(rdd, output_directory, columns_name, mode):
    """
    Save each RDD in this DStream to google storage
    Args:
        rdd: input rdd
        output_directory: output directory in google storage
        columns_name: columns name of dataframe
        mode: mode = "overwirte", overwirte the file
              mode = "append", append data to the end of file
    """
    if not rdd.isEmpty():
        (rdd.toDF( columns_name ) \
        .write.save(output_directory, format="json", mode=mode))

# %%
def saveToBigQuery(sc, output_dataset, output_table, directory):
    """
    Put temp streaming json files in google storage to google BigQuery
    and clean the output files in google storage
    """
    files = directory + '/part-*'
    subprocess.check_call(
        'bq load --source_format NEWLINE_DELIMITED_JSON '
        '--replace '
        '--autodetect '
        '{dataset}.{table} {files}'.format(
            dataset=output_dataset, table=output_table, files=files
        ).split())
    output_path = sc._jvm.org.apache.hadoop.fs.Path(directory)
    output_path.getFileSystem(sc._jsc.hadoopConfiguration()).delete(
        output_path, True)

# %%
def computeRunningSum(newValues, runningCount):
    if runningCount == None:
        runningCount = 0
    return sum(newValues) + runningCount

# %%
def hashtagCount(words):
    """
    Calculate the accumulated hashtags count sum from the beginning of the stream
    and sort it by descending order of the count.
    Ignore case sensitivity when counting the hashtags:
        "#Ab" and "#ab" is considered to be a same hashtag
    You have to:
    1. Filter out the word that is hashtags.
       Hashtag usually start with "#" and followed by a series of alphanumeric
    2. map (hashtag) to (hashtag, 1)
    3. sum the count of current DStream state and previous state
    4. transform unordered DStream to a ordered Dstream
    Hints:
        you may use regular expression to filter the words
        You can take a look at updateStateByKey and transform transformations
    Args:
        dstream(DStream): stream of real time tweets
    Returns:
        DStream Object with inner structure (hashtag, count)
    """

    # TODO: insert your code here
    stream_hashtag = words.filter(lambda v: len(v) > 1 and v[0] == '#').map(lambda v: (v.lower(), 1))
    return_hashtag = stream_hashtag.updateStateByKey(computeRunningSum).transform(lambda rdd: rdd.sortBy(lambda v: v[1], ascending = False))
    return return_hashtag

# %%
def wordCount(words):
    """
    Calculte the count of 5 sepcial words in 60 seconds for every 60 seconds (window no overlap)
    Your should:
    1. filter the words, case insensitive.
    2. count the word during a special window size
    3. add a time related mark to the output of each window, ex: a datetime type
    Hints:
        You can take a look at reduceByKeyAndWindow transformation
        Dstream is a series of rdd, each RDD in a DStream contains data from a certain interval
        You may want to take a look of transform transformation of DStream when trying to add a time
    Args:
        dstream(DStream): stream of real time tweets
    Returns:
        DStream Object with inner structure (word, count, time)
    """

    # TODO: insert your code here
    filtered_words = words.map(lambda v: v.lower()).filter(lambda word: word in WORD).map(lambda v: (v, 1))
    return_words = filtered_words.reduceByKeyAndWindow(lambda a, b: a + b, 60, 60).map(lambda v: (v[0], v[1], time.ctime()))
    
    return return_words

# %%
def saveToStorageHashTag(rdd):
    saveToStorage(rdd, output_directory_hashtags, columns_name_hashtags, "overwrite")

# %%
def saveToStorageWordCount(rdd):
    saveToStorage(rdd, output_directory_wordcount, columns_name_wordcount, "append")

# %%
if __name__ == '__main__':
    # Spark settings
    conf = SparkConf()
    conf.setMaster('local[2]')
    conf.setAppName("TwitterStreamApp")

    # create spark context with the above configuration
    sc.stop()
    SparkContext.setSystemProperty('spark.executor.memory', '16g')
    SparkContext.setSystemProperty('spark.driver.memory', '16g')
    sc = SparkContext(conf = conf)
    sc.setLogLevel("ERROR")

    # create sql context, used for saving rdd
    sql_context = SQLContext(sc)

    # create the Streaming Context from the above spark context with batch interval size 60 seconds
    ssc = StreamingContext(sc, 60)
    # setting a checkpoint to allow RDD recovery
    ssc.checkpoint("~/checkpoint_TwitterApp")

    # read data from port 9001
    dataStream = ssc.socketTextStream(IP, PORT)
    dataStream.pprint()

    words = dataStream.flatMap(lambda line: line.split(" "))

    # calculate the accumulated hashtags count sum from the beginning of the stream
    topTags = hashtagCount(words)
    topTags.pprint()

    # Calculte the word count during each time period 60s
    wordCount = wordCount(words)
    wordCount.pprint()

    # save hashtags count and word count to google storage
    # used to save to google BigQuery
    # You should:
    #   1. topTags: only save the lastest rdd in DStream
    #   2. wordCount: save each rdd in DStream
    # Hints:
    #   1. You can take a look at foreachRDD transformation
    #   2. You may want to use helper function saveToStorage
    #   3. You should use save output to output_directory_hashtags, output_directory_wordcount,
    #       and have output columns name columns_name_hashtags and columns_name_wordcount.
    # TODO: insert your code here
    
    topTags.foreachRDD(saveToStorageHashTag)
    wordCount.foreachRDD(saveToStorageWordCount)

    
    # start streaming process, wait for 600s and then stop.
    ssc.start()
    time.sleep(STREAMTIME)
    ssc.stop(stopSparkContext=False, stopGraceFully=True)
    print("Running Finished!")

    # put the temp result in google storage to google BigQuery
    saveToBigQuery(sc, output_dataset, output_table_hashtags, output_directory_hashtags)
    saveToBigQuery(sc, output_dataset, output_table_wordcount, output_directory_wordcount)
    print("Saved To BigQuery Finished!")
# Out:
# -------------------------------------------
# Time: 2019-10-31 22:51:00
# -------------------------------------------
# @LauraBaileyVO @beanprincess19 Horror movie, but instead of slasher sound effects, anytime the monsters are nearby, you hear rolling dice.RT @kollyempire: SRK - Atlee movie titled as #Sanki and announcement coming up on Nov 2nd, the star's birthday special?
#
# #Atlee #Bollywood…RT @DashieXP: So I was watching child’s play 2 and never realized there was a fire ass beat potential in this movie! I had to add some drum…RT @MikeQuindazzi: This is how #AI sees and interprets &gt;&gt;&gt; HT @Paula_Piccard and @jblefevre60 via @MikeQuindazzi &gt;&gt;&gt; #MachineLearning #Deep…RT @Roadmancode: Turkey is leading from the front in the war against the Vegans. https://t.co/aMhTconvpwI’m on #imdb cos I make the movie #filmdirector #filmcomposer #screenwriter #makingmovies  https://t.co/Ca39DqStIoThe secret to whisky's global success  https://t.co/ODPJdnVNxE # via @BBC_FutureRT @LORDY_BAR: he fucking done boo ( DOUGHBOY FROM THE MOVIE BOYZ IN THE HOOD TELLING HIS CRIPPLE CRIP HOMEY CHRIS SUN MOON STARS QUAZARS M…@yuretedancehall Oh fuck I forgot Ai.RT @BlacOnWhite69: Dammm who is she? Couple's home movie's be the best sometimes https://t.co/0PRfrRJXCART @hummus_papi: this is what I mean when I invite you over for movie night  https://t.co/d1GuOl4EGERT @Schaffrillas: Slowly coming to the realization that this is the first Halloween since Spider-Verse came out is an absolute delight http…RT @A350Blog: 42nd Singapore Airlines #A350 was DELIVERED and she is already at home.
# Reg. 9V-SMZ
#
# 81st in 2019  # 326  # MSN348
#
# 📸 A380_T…@gothyeoni its not that bad but imo somehow it just stale compared to the hype about it especially in the middle of the movie@hallmarknerd @hallmarkmovie Looking forward to seeing the movie.  Thank you for sharing.RT @storiesforghost: Not a lot of #newhorrormovies this month. But these look good! check out https://t.co/mjyvJUJYot @funhousemass @thehal…Best scary movie recommendations to watch with preteens on Halloween night? I bribed them not to go out candy colle… https://t.co/0kyRhaUwRERT @juicy_tayy: Tb to last Halloween when I took a selfie on this dudes phone cause he had a light up case n gave him my # in exchange for…RT @RealChrisCal: On this Holiest of High Basement Dweller Holidays Scope out the horror movies videos I have made! #Halloween rules and as…@EddieSteak its a good movie .watch it, its pretty deep and dark and you dont know to love or hate the guy lolRT @LLLwry: @cooperchip1 No wonder Candidate Trump had Sen Lindsey Graham Personal Cell # as a 2016 GOP Candidate
#
# REMEMBER Trump broadcas…Scary, it reminds me the West World tv show.You could say that.if I ever get my original novel written and published, I don’t want a movie. I want an ANIME.RT @C_dotDOG: Rent due https://t.co/rGD3YHlvk4My favorite part was everybody collectively walking out of the theatre crying but inspired that was A True Movie ExperienceRT @BLKLiberation84: The only REAL Harriet Tubman movie that I'll support with the legendary actress Cicely Tyson.
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:51:00
# -------------------------------------------
# ('#ai', 4)
# ('#robotics', 2)
# ('#5g', 2)
# ('#javascript', 2)
# ('#machinelearning', 2)
# ('#python', 2)
# ('#bollywood…rt', 1)
# ('#deep…rt', 1)
# ('#imdb', 1)
# ('#filmdirector', 1)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:51:00
# -------------------------------------------
# ('movie', 89, 'Thu Oct 31 22:51:06 2019')
# ('good', 8, 'Thu Oct 31 22:51:06 2019')
# ('ai', 4, 'Thu Oct 31 22:51:06 2019')
# ('spark', 6, 'Thu Oct 31 22:51:07 2019')
# ('data', 1, 'Thu Oct 31 22:51:07 2019')
#
# -------------------------------------------
# Time: 2019-10-31 22:52:00
# -------------------------------------------
# “Neither do we. Good talk.”RT @reypoullard: If you're not following .@adamscrabble, you should be. [WHY] Because he is a polymath. Scroll his timeline &amp; you'll notice…RT @springhousese: #JamesBond #NoTimeToDie #FilmProduction #Movie #BehindTheScenes
#
# Crime org. Spectre will have a significant role in NTT…RT @unreliablesteps: We're BACK, baby! Here's what our reviewer @corinna_keefe thought of Ocean's 8.
#
# [movie trailer voice] IN A WORLD WITH…RT @KeebUsman: clearly you haven't seen the movie https://t.co/kDRfFW4tH6It was a man in the suit in the movie and we thought it was funny, but this not funny? Lol@Casey Yes pls! Feels like I’m getting a repackaged spark. Nothing wrong with the spark but I kinda feel like I’m being hoodwinked.No, You Called Me as Well as Another Native the Same.
#
# You are Derailing.
# Instead of Listening, You are Clinging on… https://t.co/c6lTNdOthKBack home and ready to lay down and watch me a scary movieRT @tariqnasheed: The fact that the producers of the Harriet movie crowbarred in a Black male villain character WHO DID NOT EXIST in any hi…@cosplayhuntcrs || thank god my phone has now remembered the # and I only need to get the first few letters of 'Charlie' correct 😂😂RT @InfiniteMadrid: Marcelo: "The 2016 final against Atletico, the movie plays: Griezmann is running down the wing, and I’m marking him. Th…Tonight on Teachout Theater, Blake Edwards' "Victor/Victoria," a silly movie with some utterly wonderful moments an… https://t.co/XqsbE0Wgki@BakingCakeFGC MovieRT @juicy_tayy: Tb to last Halloween when I took a selfie on this dudes phone cause he had a light up case n gave him my # in exchange for…RT @inuzuka28: Ai:
#
# “Rin, HBD!
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:52:00
# -------------------------------------------
# ('#ai', 18)
# ('#halloween2019', 5)
# ('#원호사랑해', 5)
# ('#countdowntohalloween', 4)
# ('#artificialintelligence', 4)
# ('#bigdata', 4)
# ('#lookathernow', 4)
# ('#wonhocomeback', 4)
# ('#machinelearning', 4)
# ('#giveaway', 4)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:52:00
# -------------------------------------------
# ('good', 3, 'Thu Oct 31 22:52:08 2019')
# ('movie', 138, 'Thu Oct 31 22:52:08 2019')
# ('ai', 13, 'Thu Oct 31 22:52:08 2019')
# ('spark', 5, 'Thu Oct 31 22:52:09 2019')
# ('data', 3, 'Thu Oct 31 22:52:09 2019')
#
# -------------------------------------------
# Time: 2019-10-31 22:53:00
# -------------------------------------------
# Gather under this tweet, we are com…RT @PlayhouseHamOnt: TOMORROW - Celebrate Friday night in #HamOnt with some of the best music ever recorded, and a brand new documentary!…The next #Halloween movie is #ScoobyDoo https://t.co/gNIL0a34BXRT @C_G_Movie: #GospelMovie Clip "Break the Shackles and Run" (4) - Break Free From the Bondage of the Religious Pharisees and Return to #G…RT @facebookai: Facebook AI is sharing a new data set to enable systems to better understand actions in videos — specifically those that ar…Since it's Halloween I wanted to share some pics from my favorite vampire movie The Lost Boys.
#
# Sleep all day part… https://t.co/A1ag54GqwhRT @ChartsGhost: 'Dance Macabre' and 'Square Hammer' are on 'Ultimate Halloween' playlist, with 180,000 followers!
#
# Stream it now: https://…A testimony from my client _____ invest today and become a millionaire in few day. Inbox me to start investing toda… https://t.co/NfiA696Lhg@NASA Thank you for the interesting movie🤗
# Expect it from now on❤️#Akgeria #Algiers tonight
# #protestsRT @automeme: This shoe stitching #robot creates the most awesome shoes you have ever seen👟
# via @IntEngineering
#
# #AI #Robotics #Automation…RT @Jen_Cee76: What's your favorite scary movie? #BumpParty 💀🎃☠️👻
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:53:00
# -------------------------------------------
# ('#ai', 29)
# ('#machinelearning', 10)
# ('#halloween', 10)
# ('#원호사랑해', 7)
# ('#robotics', 6)
# ('#countdowntohalloween', 6)
# ('#bigdata', 6)
# ('#lookathernow', 6)
# ('#wonhocomeback', 6)
# ('#giveaway', 6)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:53:00
# -------------------------------------------
# ('movie', 135, 'Thu Oct 31 22:53:10 2019')
# ('ai', 12, 'Thu Oct 31 22:53:10 2019')
# ('good', 8, 'Thu Oct 31 22:53:10 2019')
# ('data', 3, 'Thu Oct 31 22:53:11 2019')
# ('spark', 7, 'Thu Oct 31 22:53:11 2019')
#
# -------------------------------------------
# Time: 2019-10-31 22:54:00
# -------------------------------------------
# Gods I love this movie.RT @No_Safe_Spaces: SAN DIEGO: Screenings start tonight in El Cajon, CA. Get your tickets for No Safe Spaces this weekend --&gt;https://t.co/u…@RaceEquityDISD @CityOfDallas We need # like #REOinthecommunity thanks for joining the panel today - together we ca… https://t.co/KeW8RqbEkLhttps://t.co/wnX0cWQhB7 Chained For Life is one of the most critically acclaimed films of 2019, an absurdly funny a… https://t.co/hP8ZgiFqODRT @mvollmer1: Superfluid World Tour highlights from Frankfurt this week in less than 1min
#
# Many thanks @A1TrickPony live from the #Superfl…RT @FloWrestling: Introduction to wrestling classes, a movie theater, five full mats, a concession area, and more.
#
# Tom Houck at Top Of The…@BunnyOnions I’m watching the hundred draft as my scary movie.2 movie tickets to the jocker pleaseRT @InfiniteMadrid: Marcelo :"The movie that plays in my head is after we won, in the dressing room. I am speaking to our kitmen, Manolín.…@Schwarzenegger @Terminator I’m really excited to see you back in action! This is my fanboy tribute to the new film… https://t.co/mzeHcQBXrAWhat is your favorite movie of the Halloween series out of these 4?RT @tariqnasheed: The fact that the producers of the Harriet movie crowbarred in a Black male villain character WHO DID NOT EXIST in any hi…@j_ssiiccaa @PlayAdoptMe They deleted the tweet fml but they posted it the same day they revealed the house. The tw… https://t.co/n7HtCgBIoART @SympLySimi: So Nike made me sit through this useless movie. I deserve better. Fuck you bish @FatGirlwithin_@NoelMu My wife and I have Classic Movie Wednessay and last night we picked HOUSE! Crazy great!Nice AI video for everyone, with a lot what-ifsSabi ko one more movie hehehe until I heard the birds chirping hahahahahha I should sleeeeep!RT @JohnNosta: Big Data Can Improve the Health of the World’s Most Vulnerable: Mothers and Children https://t.co/cqfj4iNbW7  #bigdata #data…@EmpereurGlory Osef j'ai wakanim crunchyroll ADN Netflix OCS :)There is not one single thing I dislike about the movie The Longest Ride. Best love movie I’ve seen. And Scott Eastwood is 🥵Now imagine that but with the Suicide Squad. It’s why a lot of us are hyped.RT @DidymusBrush: The tension in this sequence is INCREDIBLE. THIS is what every found footage horror movie since has been trying to mimic.…3⃣ NEW POST 3⃣
#
# Great reviews these are! Our team got together again to discuss the 3rd movie in the @StarWars chro… https://t.co/46Vog2B6vmRT @flickertomykiwi: @harrsttyless i CANT WITH MYSELF NSJFJWJX I KNEW THERE WAS SOMETHING MISSING AND I WAS LIKE "???" WAIT WHERES THE # SX…@PropheticMemes1 Bonjour the unroll you asked for: Thread by @PropheticMemes1: "Post # 77 - Q1675: Trump has just g… https://t.co/kdNXNv5bAxRT @TeewhyInfamous: @LilFr3ddy @PodTier @KCMIA90 @Raccitup @KillaKroog @TheReal_Deizal @yuLoveCoffee Everybody Gon do what they do... but I…Still the best movie my friends.   I need you emailWhuuuuuht?! It's not a movie for kids anymore?! Ya don't say!RT @MovieErotic: Full Movie Links
#
# 🔜 https://t.co/rbkxyp3fkm
# 🔜 https://t.co/EjheQo3LMC
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:54:00
# -------------------------------------------
# ('#ai', 37)
# ('#machinelearning', 14)
# ('#halloween', 14)
# ('#원호사랑해', 9)
# ('#lookathernow', 8)
# ('#wonhocomeback', 8)
# ('#giveaway', 8)
# ('#933kobfmtakeover', 8)
# ('#wemadeit', 8)
# ('#robotics', 7)
# ...
# -------------------------------------------
# Time: 2019-10-31 22:54:00
# -------------------------------------------
# ('movie', 131, 'Thu Oct 31 22:54:08 2019')
# ('ai', 11, 'Thu Oct 31 22:54:08 2019')
# ('good', 4, 'Thu Oct 31 22:54:08 2019')
# ('data', 3, 'Thu Oct 31 22:54:09 2019')
# ('spark', 11, 'Thu Oct 31 22:54:09 2019')
#
# -------------------------------------------
# Time: 2019-10-31 22:55:00
# -------------------------------------------
# #HalloweenFridayFashion Therapy # 1475 https://t.co/eopUUiBcJc https://t.co/8NKh8RKt48@AllieGoertz I love everything about that movie. Great writing, acting, directing, and an awesome soundtrack as wel… https://t.co/PmBk6BJeFfRT @catsuka: Animations from "The Legend Of Hei" chinese movie.
# This is the last (31/31) daily post of my #LegendOfHeInktober series.
# Thank…Earned 2 PSN trophies (1 silver and 1 bronze) in AI: The Somnium Files https://t.co/nTSesb1NfaLong before James Gunn rose to total pop-culture prominence with the two 'Guardians of the Galaxy' films, he direct… https://t.co/1EGUGGZifjRT @sgtottersberg: [TRANS] The other Queendom participants talk about what Oh My Girl are to them
#
# Oh My Girl are... # ReactionMasters
# Oh M…RT @dabi_hawks: ANYWAY if you type "Google drive" after a movie title in your search bar then you'll probably find pretty much any movie ou…RT @GingaSnapppa: If you’re not watching a scary movie tonight, what’s wrong with you ?RT @_adreammss: Fresno niggas skipped this part of the movie 🙄 https://t.co/stx1JqEnnrlisten. this song was one of my faves off of DD. this mv was peak art for me. the pain i lived for. the stuff i wan… https://t.co/UhIMwncxYWRT @AllahCanceledMe: your wcw getting fucked to an a24 movie tonight it's over broRT @javi_draws: Mom: you know that movie "amazing animals" ??
# Me: what
# Mom: the one where he has animals in his suitcase
# Me: FANASTIC BEAS…@seahawksnerd75 Ted out here refreshing his notifications and is upset his # s are low😂Uma is drag excellence in this movie. https://t.co/YOLChcYGf2RT @porpentina2017: It's party time!
#
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:55:00
# -------------------------------------------
# ('#ai', 46)
# ('#machinelearning', 17)
# ('#halloween', 17)
# ('#원호사랑해', 11)
# ('#wonhocomeback', 9)
# ('#bigdata', 8)
# ('#lookathernow', 8)
# ('#giveaway', 8)
# ('#933kobfmtakeover', 8)
# ('#wemadeit', 8)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:55:00
# -------------------------------------------
# ('movie', 137, 'Thu Oct 31 22:55:08 2019')
# ('good', 9, 'Thu Oct 31 22:55:08 2019')
# ('ai', 11, 'Thu Oct 31 22:55:08 2019')
# ('spark', 5, 'Thu Oct 31 22:55:09 2019')
# ('data', 1, 'Thu Oct 31 22:55:09 2019')
#
# -------------------------------------------
# Time: 2019-10-31 22:56:00
# -------------------------------------------
# ...and a ton of My Little Pony!…@frau_lol @infernus_ascent @PSA_Sitch From a narrative stand point, he doing that actually makes sense. Plus, the a… https://t.co/kPZTphWEOjRT @caroletwitt_: 4 #EmergingTech predictions for 2025
# 1) #3Dprinted human organ transplant
# 2) #3Dprint cars
# 3) Implantable #smartphones
# 4)…RT @amature_star69: Movie night! https://t.co/IUJD4qrqjjRT @JoelGoldenberg1: @thedavidcrosby At my local movie theater, I had the choice of seeing Remember My Name or Echo in the Canyon. Glad I s…ATTENTION: Luisito Comunica, the voice of Sonic in Latin America, is recording new lines for Sonic TODAY. Don't kno… https://t.co/Xf7VRUwYnQRT @kingvader: Hood Naruto The Movie (trailer) https://t.co/RHnxL9qRx3RT @TAMPA_DREADHEAD: @tariqnasheed A pg-13 slave movie, I think they made this so they can play it in schools and re-white history.@90spreston Just Like A Movie is the best Wallows songRT @Countdown: Happy Halloween! We're celebrating the final #Giveaway of our #CountdownToHalloween with a $250 @Visa Gift Card. RT to enter…RT @KingdomGospelRa: 🙏 https://t.co/mdALb9bmKW
# 🎬Gospel Movie "The Mystery of Godliness" (6) - The Necessity for God to Do His Work Through…RT @hallmarkmovie: When Anne @RealBrookeD and Keith @TrevDon are brought together unexpectedly, they’ll experience a holiday season like no…RT @angies_code: We are going strong with 3 # trending WW! We will fight until you come back to us again!
#
# 2. #원호사랑해
#
# 5. #WONHOCOMEBACK
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:56:00
# -------------------------------------------
# ('#ai', 57)
# ('#halloween', 22)
# ('#machinelearning', 20)
# ('#원호사랑해', 18)
# ('#wonhocomeback', 16)
# ('#วาร์ปสิวะ', 12)
# ('#jav', 10)
# ('#lookathernow', 9)
# ('#giveaway', 9)
# ('#933kobfmtakeover', 9)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:56:00
# -------------------------------------------
# ('movie', 126, 'Thu Oct 31 22:56:08 2019')
# ('ai', 8, 'Thu Oct 31 22:56:08 2019')
# ('good', 6, 'Thu Oct 31 22:56:08 2019')
# ('spark', 3, 'Thu Oct 31 22:56:09 2019')
#
# -------------------------------------------
# Time: 2019-10-31 22:57:00
# -------------------------------------------
# 16…RT @JK_Peru: Interacciones de pro-gamers, youtubers, ligas de Overwatch bajo el reciente tuit de Jungkook en @BTS_twt 🕹️
#
# —Equipos: All Kni…RT @tariqnasheed: The fact that the producers of the Harriet movie crowbarred in a Black male villain character WHO DID NOT EXIST in any hi…RT @ParalivesHub: Updated features list:
#
# Advanced build tools
# An open world neighborhood
# Fully customizable buildings and furniture
# Advanc…RT @ajhinch: Thank you @astros fans for a memorable 2019 season. From standout player performances to a franchise record # of wins to clinc…RT @realDerekUtley: For decades, scientists have said we are at risk of dying from global warming.
#
# Now, they say an ice age is coming?…We back chatting some #starwars, Revenge of the Sith time! Come read what we thought about the final film in the pr… https://t.co/4GjM5WiwQJRT @AmandaRosenberg: this year gave us Tall Girl and Little Women which means there’s room for my movie Middle Bitches2nd Movie?????Okay let me cook real quick so we can get into these movies.. idk what I should pick for scary movie might 🤔🤔RT @tariqnasheed: The fact that the producers of the Harriet movie crowbarred in a Black male villain character WHO DID NOT EXIST in any hi…RT @angies_code: We are going strong with 3 # trending WW! We will fight until you come back to us again!
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:57:00
# -------------------------------------------
# ('#ai', 68)
# ('#원호사랑해', 25)
# ('#halloween', 25)
# ('#wonhocomeback', 23)
# ('#machinelearning', 23)
# ('#วาร์ปสิวะ', 12)
# ('#robotics', 11)
# ('#legendofheinktober', 10)
# ('#bigdata', 10)
# ('#lookathernow', 10)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:57:00
# -------------------------------------------
# ('movie', 105, 'Thu Oct 31 22:57:09 2019')
# ('good', 4, 'Thu Oct 31 22:57:09 2019')
# ('ai', 8, 'Thu Oct 31 22:57:09 2019')
# ('spark', 4, 'Thu Oct 31 22:57:09 2019')
# ('data', 2, 'Thu Oct 31 22:57:09 2019')
#
# -------------------------------------------
# Time: 2019-10-31 22:58:00
# -------------------------------------------
# If the Bears can beat the…Vegans and I have nothing in common because the most disturbing part of this video to me was the pointless rose pet… https://t.co/2BLoNmd2D7RT @kasthq: Halloween Flash Sale! Become a Kast Founder and get the iOS app for 50% off, today only. Join one of our many Horror Movie Kast…@HadeexahHamza But u ladies don't want to marry d hustlers ai, u re neither for d chima zaune's nor d hustlers but… https://t.co/PG6megFVSpRT @XPRES__: The enemy AI in Modern Warfare called me a nigger… Call of Duty’s back, babyyyy!!RT @arvalis: There should be a dinosaur ghost movie. Basically everywhere is a dinosaur burial ground. https://t.co/OS0bXNpPCgRT @Countdown: Happy Halloween! We're celebrating the final #Giveaway of our #CountdownToHalloween with a $250 @Visa Gift Card. RT to enter…Okay hear me out: a Rush Hour/Bad Boys crossover movie.Ladies and gentlemen, we would like to request that you all stay until the investigation is completed. Catch Knives… https://t.co/8XTtfCPHJyThis is Atlantis erasure@ag_due When I moved to my neighborhood there were few actual kids and a lot of close retirement ppl. But they did… https://t.co/fU7eb71F1dRT @hyoreos: Seongwu new fc post
#
# “Heuttcya~~ 🕺🏻”
#
# He showed pics of him practicing dance for the movie i guess UwU
#
# #옹성우 #OngSeongwu #องซ…RT @MAINEnatics_UAE: Showing na po ang Isa Pa With Feelings dito sa UAE! Enjoy po kayo sa movie and see you all ulit tomorrow for our block…I wanna watch The Keep right noe. Irs beautiful and rhe music is amazinf. I love that movie!RT @NathanZed: When the subtitles spoil the movie https://t.co/6YFUoY6jojRT @dabi_hawks: ANYWAY if you type "Google drive" after a movie title in your search bar then you'll probably find pretty much any movie ou…Could electric roads spark a green transport revolution? https://t.co/IPnDNwZPMmRT @genericgaystuff: Horror movie bitches when a demon appears in the corner of the room https://t.co/04L5QFEAxTRT @yukinowins: Luigi’s Mansion for the day and pizza and a movie tonight. Halloween is perfect rnThis the first Halloween I'm not dressing up... But my fiance got us candy and we're gunna watch a spooky movie!RT @309KTYSS: Chungha played Taeyeon’s Spark, said it’s her favorite song 💜
#
# She said she’s listening to all the songs on the album &amp; was…RT @TaikaWaititi: WATCH MY MOVIE! https://t.co/AxnL1RkNp2@pessoas_zn Nd haver isso aiLove Jones lol@BKuzan Movie magic lolJust watched Trick R’ Treat for the first time ever.
#
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:58:00
# -------------------------------------------
# ('#ai', 79)
# ('#원호사랑해', 30)
# ('#wonhocomeback', 28)
# ('#halloween', 28)
# ('#machinelearning', 24)
# ('#legendofheinktober', 19)
# ('#วาร์ปสิวะ', 14)
# ('#robotics', 12)
# ('#jav', 12)
# ('#giveaway', 11)
# ...
# -------------------------------------------
# Time: 2019-10-31 22:58:00
# -------------------------------------------
# ('movie', 130, 'Thu Oct 31 22:58:09 2019')
# ('ai', 8, 'Thu Oct 31 22:58:09 2019')
# ('good', 4, 'Thu Oct 31 22:58:09 2019')
# ('spark', 8, 'Thu Oct 31 22:58:09 2019')
# ('data', 1, 'Thu Oct 31 22:58:09 2019')
#
# -------------------------------------------
# Time: 2019-10-31 22:59:00
# -------------------------------------------
# Thank you to… https://t.co/hYdiOSZfIbVote for #WeMadeIt! 😁RT @dabi_hawks: ANYWAY if you type "Google drive" after a movie title in your search bar then you'll probably find pretty much any movie ou…Girl the eeriness of this movie..... like who knew being in broad day light in the middle of Sweden was spooking me@ThatKevinSmith @LAWeekly When will we get to see the movie in Australia @ThatKevinSmithRT @Neeky96: And this is me running to see the movie when it comes out 😍
# Can't wait for it 😍 #TheKillingOfTwoLovers #ClayneCrawford @Clayne…@TondarSarkazian A deep movieDecorations are up and I’ve got 13 Ghosts on Blu-ray (the best little horror movie you’re never going to find  anyw… https://t.co/Iy5nfc9E5u@AmyinSydney Hope you enjoy the movie, it's great!@pulte @pulte My favorite childhood movie me and the fam went to work like this😂 https://t.co/YC2BhCg6z1@della_morte_ @BipolarAndrew @DuanSparkles @Nymphomachy @AntifaSarkeesi1 That awful fucking movie even managed to s… https://t.co/dAG4StUcExDigimon Movie without aRT @andyzengtweets: Can robots learn to pick up stuff and accurately toss them into bins outside its natural range? Check out our latest wo…Stealing someone else's tweet, but we can all agree that the DeLorean from Back to the Future is the top movie car of all time, right?Watching Halloween 3, which is objectively the best Halloween movie.RT @precedentSPORTS: @Pumabad_minton wins at #state semi finals, will face Huskies for title tonight https://t.co/bvpPWSrKAz #me watching the hellboy movie https://t.co/Tkz544txFORT @Blanco_bob: 📞What’s your favorite scary movie?
#
# 🎃HAPPY ANOMA WEEN🎃
# Pics by @simplifiCARLA and joseph
#
# #halloween2019 #Scream #CaseyBec…RT @Jordan_Sather_: Climate change extremists are falling for fake science.
#
# True science shows that solar and cosmic effects influence o…RT @TeamSonicESP: ATTENTION: Luisito Comunica, the voice of Sonic in Latin America, is recording new lines for Sonic TODAY. Don't know if t…@cIairenvk @casdean_s What movie?!?Spark your child's imagination with these easy to use ideas. Candlewick Press kid lit is perfect for igniting your… https://t.co/cbiilnc0aQRT @NathanZed: When the subtitles spoil the movie https://t.co/6YFUoY6jojRT @16bitbulbasaur: [on a movie date]
#
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:59:00
# -------------------------------------------
# ('#ai', 87)
# ('#원호사랑해', 36)
# ('#wonhocomeback', 33)
# ('#halloween', 31)
# ('#machinelearning', 26)
# ('#legendofheinktober', 23)
# ('#lookathernow', 19)
# ('#933kobfmtakeover', 19)
# ('#wemadeit', 19)
# ('#วาร์ปสิวะ', 16)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 22:59:00
# -------------------------------------------
# ('movie', 128, 'Thu Oct 31 22:59:06 2019')
# ('good', 7, 'Thu Oct 31 22:59:06 2019')
# ('ai', 7, 'Thu Oct 31 22:59:06 2019')
# ('spark', 7, 'Thu Oct 31 22:59:07 2019')
#
# -------------------------------------------
# Time: 2019-10-31 23:00:00
# -------------------------------------------
# #WONHOCOMEBACK #WeLoveWonho https://t.co/jpczvo8SeR“Hoes ain’t shit happy Halloween” I’m dead💀💀💀RT @up10tiontrans: [#SUNYOUL  /FC - FREE TALK @ 191028 18:06]
# 🐰It's a good life
#
# ㅠㅅㅠ
#
# (Image: listening to Taeyeon's Spark) https://t.co/z3…RT @TaikaWaititi: WATCH MY MOVIE! https://t.co/AxnL1RkNp2RT @LightsCameraPod: What is your FAVORITE MOVIE of all time?
#
# Apple: https://t.co/DpjuUp7a2E
# Spotify: https://t.co/zDsu3CQveI https://t.co…do @jiwongIow know this ?RT @MCUExchange: "The movie hits you like a shot in the heart."
#
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:00:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:00:00
# -------------------------------------------
# ('good', 8, 'Thu Oct 31 23:00:08 2019')
# ('movie', 127, 'Thu Oct 31 23:00:08 2019')
# ('ai', 7, 'Thu Oct 31 23:00:08 2019')
# ('spark', 9, 'Thu Oct 31 23:00:09 2019')
# ('data', 1, 'Thu Oct 31 23:00:09 2019')
#
# -------------------------------------------
# Time: 2019-10-31 23:01:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:01:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:01:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:02:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:02:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:02:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:03:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:03:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:03:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:04:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:04:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:04:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:05:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:05:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:05:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:06:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:06:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:06:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:07:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:07:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
# -------------------------------------------
# Time: 2019-10-31 23:07:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:08:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:08:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:08:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:09:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:09:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:09:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:10:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:10:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:10:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:11:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:11:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:11:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:12:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-10-31 23:12:00
# -------------------------------------------
# ('#ai', 94)
# ('#원호사랑해', 45)
# ('#wonhocomeback', 42)
# ('#halloween', 34)
# ('#machinelearning', 28)
# ('#legendofheinktober', 24)
# ('#lookathernow', 22)
# ('#933kobfmtakeover', 22)
# ('#wemadeit', 22)
# ('#วาร์ปสิวะ', 18)
# ...
#
# -------------------------------------------
# Time: 2019-10-31 23:12:00
# -------------------------------------------
#
# Running Finished!
# Saved To BigQuery Finished!
